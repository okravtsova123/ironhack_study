# %%
import pandas as pd

sharks_df=pd.read_excel("https://www.sharkattackfile.net/spreadsheets/GSAF5.xls")

# %%
sharks_df.tail(50)
# Out:
#                                                    Date  Year        Type  \
# 6907                                        Before 1927   0.0  Unprovoked
# 6908                                Between 1918 & 1939   0.0  Unprovoked
# 6909                                            No date   0.0  Unprovoked
# 6910                                            No date   0.0  Unprovoked
# 6911                                            No date   0.0  Unprovoked
# 6912                                         1920 -1923   0.0  Unprovoked
# 6913                                        Before 1921   0.0  Unprovoked
# 6914                                        Before 1911   0.0  Unprovoked
# 6915                                        Before 1921   0.0  Unprovoked
# 6916                                        Before 1921   0.0  Unprovoked
# 6917                                        Before 1917   0.0  Unprovoked
# 6918                                 Before 17-Jul-1916   0.0  Unprovoked
# ...

# %%
sharks_df.describe(include="object")
# Out:
#         Date        Type Country    State                          Location  \
# count   6932        6914    6882     6451                              6368
# unique  5992          11     224      896                              4503
# top     1957  Unprovoked     USA  Florida  New Smyrna Beach, Volusia County
# freq       9        5098    2536     1178                               191
#
#        Activity  Name   Sex   Age Injury  ...       Time     Species   \
# count      6347  6713  6353  3942   6897  ...       3410         3804
# unique     1586  5677     8   243   4076  ...        410         1674
# top     Surfing  male     M    19  FATAL  ...  Afternoon  White shark
# freq       1120   676  5570    89    860  ...        215          194
#
#                                  Source                        pdf  \
# count                              6913                       6799
# unique                             5291                       6789
# ...

# %%
sharks_df["Injury"].unique()
# Out:
# array(['Leg bitten',
#        'Provoked incident. Lacerations and puncture wounds to hand and calf from hooked shark ',
#        'FATAL', ..., 'FATAL, leg stripped of flesh  ',
#        'FATAL, knocked overboard by tail of shark & carried off by shark ',
#        'FATAL. "Shark bit him in half, carrying away the lower extremities" '],
#       dtype=object)

# %%
sharks_df["Date"].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sharks_df["Date"].min()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11669, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, numeric_only, **kwargs)
#   11650 @doc(
#   11651     _num_doc,
#   11652     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11667     **kwargs,
#   11668 ):
# > 11669     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11169, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11162 def min(
#   11163     self,
#   11164     axis: Axis | None = 0,
#    (...)
#   11167     **kwargs,
#   11168 ):
# > 11169     return self._stat_function(
#   11170         "min",
#   11171         nanops.nanmin,
#   11172         axis,
# ...
