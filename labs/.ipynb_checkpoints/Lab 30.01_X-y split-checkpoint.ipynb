# %%
import pandas as pd
import seaborn as sn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer

# %%
df=pd.read_csv('https://raw.githubusercontent.com/okravtsova123/ironhack_study/main/labs/python_lab_2901/marketing_customer_analysis_clean.csv')

# %%
# Exercise 1.
# Hint: use the file Data_Marketing_Customer_Analysis_Round3.csv
# One Hot/Label Encoding of the categorical variables in the categoricals data frame that you created in Activity 3. ( Hint: check Dropfirst option).
# for the first iteration, we will focus on the numericals data (numericals data frame) as our data source
df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
df.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
#getting the object columns into categorical df to devide them into the nominals and ordinals
df_category=df.select_dtypes(include='object')
df_category
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College        2011-02-18
# 1      KX64629  California       No     Basic   College        2011-01-18
# 2      LZ68649  Washington       No     Basic  Bachelor        2011-02-10
# 3      XL78013      Oregon      Yes  Extended   College        2011-01-11
# 4      QA50777      Oregon       No   Premium  Bachelor        2011-01-17
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor        2011-01-19
# 10906  KX53892      Oregon       No     Basic   College        2011-01-06
# 10907  TL39050     Arizona       No  Extended  Bachelor        2011-02-06
# 10908  WA60547  California       No   Premium   College        2011-02-13
# 10909  IV32877  California       No     Basic  Bachelor        2011-01-08
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
#deviding df_category; separating nominals
df_category_nominals=df_category[['state','response', 'employmentstatus','gender', 'location_code', 'marital_status', 'policy', 'renew_offer_type', 'sales_channel',"vehicle_class", "vehicle_type"]]
df_category_nominals
# Out:
#             state response employmentstatus gender location_code  \
# 0         Arizona       No         Employed      M      Suburban
# 1      California       No       Unemployed      F      Suburban
# 2      Washington       No         Employed      M      Suburban
# 3          Oregon      Yes         Employed      M      Suburban
# 4          Oregon       No    Medical Leave      F      Suburban
# ...           ...      ...              ...    ...           ...
# 10905      Nevada       No       Unemployed      F      Suburban
# 10906      Oregon       No         Employed      F         Urban
# 10907     Arizona       No         Employed      F         Rural
# 10908  California       No         Employed      F         Urban
# 10909  California       No       Unemployed      M      Suburban
#
#       marital_status        policy renew_offer_type sales_channel  \
# 0            Married  Corporate L3           Offer3         Agent
# ...

# %%
#transforming nominals for ML
df_category_nominals=pd.get_dummies(df_category_nominals, dtype=int)
df_category_nominals
# Out:
#        state_Arizona  state_California  state_Nevada  state_Oregon  \
# 0                  1                 0             0             0
# 1                  0                 1             0             0
# 2                  0                 0             0             0
# 3                  0                 0             0             1
# 4                  0                 0             0             1
# ...              ...               ...           ...           ...
# 10905              0                 0             1             0
# 10906              0                 0             0             1
# 10907              1                 0             0             0
# 10908              0                 1             0             0
# 10909              0                 1             0             0
#
#        state_Washington  response_No  response_Yes  employmentstatus_Disabled  \
# 0                     0            1             0                          0
# ...

# %%
#deviding df_category; separating ordinals
df_category_ordinals=df_category[['coverage', 'education',"vehicle_size"]]
df_category_ordinals
# Out:
#        coverage education vehicle_size
# 0         Basic   College      Medsize
# 1         Basic   College      Medsize
# 2         Basic  Bachelor      Medsize
# 3      Extended   College      Medsize
# 4       Premium  Bachelor      Medsize
# ...         ...       ...          ...
# 10905   Premium  Bachelor      Medsize
# 10906     Basic   College      Medsize
# 10907  Extended  Bachelor      Medsize
# 10908   Premium   College      Medsize
# 10909     Basic  Bachelor      Medsize
#
# [10910 rows x 3 columns]

# %%
#maping ordinals
df_category_ordinals['education'].unique()
df_category_ordinals['education']=df_category_ordinals['education'].map({"High School or Below": 1, "College": 2, "Bachelor": 3, "Master": 4, "Doctor": 5})
df_category_ordinals['education']

df_category_ordinals['vehicle_size'].unique()
df_category_ordinals['vehicle_size']=df_category_ordinals['vehicle_size'].map({'Small': 1, 'Medsize': 2, 'Large': 3})
df_category_ordinals['vehicle_size']

df_category_ordinals['coverage'].unique()
df_category_ordinals['coverage']=df_category_ordinals['coverage'].map({'Basic': 1, 'Extended': 2, 'Premium': 3})
df_category_ordinals['coverage']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23040\1113231941.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_category_ordinals['education']=df_category_ordinals['education'].map({"High School or Below": 0, "College": 1, "Bachelor": 2, "Master": 3, "Doctor": 4})
# C:\Users\user\AppData\Local\Temp\ipykernel_23040\1113231941.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#separating numericals from the original dataset
df_numerical=df.select_dtypes(include='number')
df_numerical
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %%
df_category=pd.concat([df_category_nominals, df_category_ordinals], axis=1)
df_category
# Out:
#        state_Arizona  state_California  state_Nevada  state_Oregon  \
# 0                  1                 0             0             0
# 1                  0                 1             0             0
# 2                  0                 0             0             0
# 3                  0                 0             0             1
# 4                  0                 0             0             1
# ...              ...               ...           ...           ...
# 10905              0                 0             1             0
# 10906              0                 0             0             1
# 10907              1                 0             0             0
# 10908              0                 1             0             0
# 10909              0                 1             0             0
#
#        state_Washington  response_No  response_Yes  employmentstatus_Disabled  \
# 0                     0            1             0                          0
# ...

# %%
# THE FINAL ONES TO WORK WITH
df_numerical
df_category
# Out:
#        state_Arizona  state_California  state_Nevada  state_Oregon  \
# 0                  1                 0             0             0
# 1                  0                 1             0             0
# 2                  0                 0             0             0
# 3                  0                 0             0             1
# 4                  0                 0             0             1
# ...              ...               ...           ...           ...
# 10905              0                 0             1             0
# 10906              0                 0             0             1
# 10907              1                 0             0             0
# 10908              0                 1             0             0
# 10909              0                 1             0             0
#
#        state_Washington  response_No  response_Yes  employmentstatus_Disabled  \
# 0                     0            1             0                          0
# ...

# %% [markdown]
# #TASK 2

# %%
#varA
print(df_numerical['total_claim_amount'].mean())
print(df_numerical['total_claim_amount'].std())     
print(df_numerical['total_claim_amount'].hist())
# Out:
# 434.8883297028414
# 292.180555965428
# Axes(0.125,0.11;0.775x0.77)

# %%
#Use minmax transform to bring varA's values into the range [0,1].
#Check that varA has been rescaled using a displot or a histogram

var_a=df_numerical[['total_claim_amount']]
m_scaler=MinMaxScaler()
df_numerical['total_claim_amount']=m_scaler.fit_transform(var_a)

# %%
#checking new hist

print(df_numerical['total_claim_amount'].mean())
print(df_numerical['total_claim_amount'].std())  
print(df_numerical['total_claim_amount'].hist())
# Out:
# 0.15028281447253605
# 0.10099078793304499
# Axes(0.125,0.11;0.775x0.77)

# %%
#varB
#Use StandardScaler to standardize the variable or PowerTransform to reduce its skew.
#Check that the result has zero mean, unit variance, and reduced skew using mean(), std(), and a plot of the PDF.

df_numerical['customer_lifetime_value'].hist()

var_b=df_numerical[['customer_lifetime_value']]
s_scaler=StandardScaler()
df_numerical['customer_lifetime_value']=s_scaler.fit_transform(var_b)

# %%
print(df_numerical['customer_lifetime_value'].mean())
print(df_numerical['customer_lifetime_value'].std())     
print(df_numerical['customer_lifetime_value'].hist())
# Out:
# -1.426295684064729e-16
# 1.000045832664961
# Axes(0.125,0.11;0.775x0.77)

# %%
pt=PowerTransformer()
var_b_scaled_power=pt.fit_transform(var_b_scaled)
df_numerical['customer_lifetime_value']=var_b_scaled_power

# %%
print(df_numerical['customer_lifetime_value'].mean())
print(df_numerical['customer_lifetime_value'].std())  
print(df_numerical['customer_lifetime_value'].hist())
# Out:
# -2.2143403314246934e-17
# 1.0000458326649653
# Axes(0.125,0.11;0.775x0.77)
