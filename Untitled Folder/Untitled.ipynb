# %%
import pandas as pd

# %%
df=pd.read_csv('customer_conversion_testing_dataset.csv')

# %%
df
# Out:
#        LeadID  Age  Gender    Location    LeadSource  TimeSpent (minutes)  \
# 0           1   60  Female      Lahore       Organic                   46
# 1           2   27    Male      Lahore         Email                   42
# 2           3   21    Male     Sialkot         Email                   56
# 3           4   37  Female      Quetta       Organic                   24
# 4           5   35  Female      Quetta         Email                   39
# ...       ...  ...     ...         ...           ...                  ...
# 26140   26141   57  Female     Sialkot      Referral                   15
# 26141   26142   34    Male   Islamabad         Email                   30
# 26142   26143   44  Female  Gujranwala  Social Media                   10
# 26143   26144   20    Male  Rawalpindi  Social Media                   60
# 26144   26145   22    Male  Faisalabad      Referral                   41
#
#        PagesViewed LeadStatus  EmailSent DeviceType ReferralSource  \
# ...

# %%
df[df['Conversion (Target)']==1].count()
# Out:
# LeadID                   413
# Age                      413
# Gender                   413
# Location                 413
# LeadSource               413
# TimeSpent (minutes)      413
# PagesViewed              413
# LeadStatus               413
# EmailSent                413
# DeviceType               413
# ReferralSource           413
# FormSubmissions          413
# Downloads                413
# CTR_ProductPage          413
# ResponseTime (hours)     413
# FollowUpEmails           413
# SocialMediaEngagement    413
# PaymentHistory           413
# Conversion (Target)      413
# dtype: int64
